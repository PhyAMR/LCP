# %% [markdown]
# ### CNNs applied to time series

# %%
import numpy as np
import matplotlib.pyplot as plt
plt.rcParams['font.size'] = 14

import keras
import tensorflow as tf
from keras.models import Sequential
from keras.layers import Dense, Dropout, Flatten #, Reshape
from keras.layers import Conv1D, MaxPooling1D, AveragePooling1D

# %run plot.py
# Out:
# 2026-03-16 23:21:37.989911: I external/local_xla/xla/tsl/cuda/cudart_stub.cc:31] Could not find cuda drivers on your machine, GPU will not be used.
# 2026-03-16 23:21:37.990767: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2026-03-16 23:21:38.138178: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2026-03-16 23:21:41.325472: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2026-03-16 23:21:41.326240: I external/local_xla/xla/tsl/cuda/cudart_stub.cc:31] Could not find cuda drivers on your machine, GPU will not be used.

# %% [markdown]
# ### Read data

# %%
str0 = 'ts_L60_Z12_A500_DX50_bias5_N10000.dat'
fnamex='DATA/x_'+str0
fnamey='DATA/y_'+str0

x = np.loadtxt(fnamex, delimiter=" ",dtype=float)
# number of samples, number of features
N,L = len(x), len(x[0])

Show_data(x,L,"original data")

categ = np.loadtxt(fnamey, dtype=int)
n_class = 3    # y.argmax() - y.argmin() +1
print('data: ',N)
print(categ.shape)
y = np.zeros((N,n_class))
for i in range(N):
    y[i][categ[i]] = 1. # y contains one-hot encoding
print('y shape: ',y.shape)
# Out:
# data:  10000
# (10000,)
# y shape:  (10000, 3)

# %% [markdown]
# ### Split train-validation and rescale

# %%
# split into training and validation sets
perc_train=0.8
N_train = int(perc_train*N)
x_train = x[:N_train]
print(x_train.shape)
y_train = y[:N_train]
x_val = x[N_train:]
y_val = y[N_train:]
N_val = len(x_val)
print('N_train=',N_train,'  N_val=',N_val,'  L=',L,'  n_class=',n_class)

 
#remove average value of each sample from its values
xm_train = x_train.mean(axis=1)
std_train = x_train.std(axis=1)
xm_val = x_val.mean(axis=1)
std_val = x_val.std(axis=1)
print('std_train average and mean:',max(std_train), min(std_train), std_train.mean(axis=0))
print('std_val average and mean:',max(std_val), min(std_val), std_val.mean(axis=0))

# rescale with variance on the training set
for i in range(N_train):
    #x_train[i] = (x_train[i]-xm_train[i])/ std_train[i] #not good, std_train is very variable across samples
     #x_train[i] = (x_train[i]-xm_train[i])/ 400 #crude rescaling, variance should be used
     x_train[i] = (x_train[i]-xm_train[i])/ std_train.mean(axis=0)
for i in range(N_val):
    #x_val[i] = (x_val[i]-xm_val[i])/ std_val[i]
    #x_val[i] = (x_val[i]-xm_val[i])/ 400
    x_val[i] = (x_val[i]-xm_val[i])/ std_val.mean(axis=0)
#

    
Show_data(x_train,L,"rescaled train data")
Show_data(x_val,L,"rescaled validation data")

#x_train=x_train.astype("float32")
#y_train=y_train.astype("float32")
#x_val=x_val.astype("float32")
#y_val=y_val.astype("float32")

# Keras wants an additional dimension with a 1 at the end
x_train = x_train.reshape(x_train.shape[0], L, 1)
x_val =  x_val.reshape(x_val.shape[0], L, 1)
input_shape = (L, 1) # number of features, number of channels (1 for 1D data)
print(y_train.shape, y_val.shape, x_train.shape, x_val.shape)
# Out:
# (8000, 60)
# N_train= 8000   N_val= 2000   L= 60   n_class= 3
# std_train average and mean: 588.25397835931 44.84287073276593 201.46657645528722
# std_val average and mean: 569.9090424503428 55.06717110341998 201.92178219610327
# (8000, 3) (2000, 3) (8000, 60, 1) (2000, 60, 1)

# %% [markdown]
# ## Convolutional NN

# %%
# ...LESSON ...
# reproducibility
np.random.seed(12345)
import tensorflow.random as tf_r
tf_r.set_seed(12345)

## from keras import regularizers, initializers

reg = tf.keras.regularizers.l2(0.2) ## raised to 0.2 the regularization strenghts
#reg = regularizers.l1(0.1)
ini = tf.keras.initializers.RandomNormal(mean=0.0, stddev=0.05, 
                                        seed=None)
NCONV = 1 #swtich between 1 and 2 CNNs
NF = 5 #number of filters

# challenge: at most 600 tunable parameters
model = Sequential()
# 
if NCONV==1:
    # -----2-----
    model.add(Conv1D(filters=NF, kernel_size=11, 
                     kernel_initializer=ini, 
                     kernel_regularizer=reg,
                     activation='relu', 
                     input_shape=input_shape))
    #model.add(MaxPooling1D(3))
    model.add(AveragePooling1D(5))
    model.add(Conv1D(filters=5, kernel_size=7, 
                     activation='relu'))
    model.add(Flatten())
    model.add(Dense(12, activation='relu'))
    model.add(Dropout(0.2))
# 
if NCONV==2:
    # -----1-----
    model.add(Conv1D(filters=NF, kernel_size=11, 
                     kernel_initializer=ini, 
                     kernel_regularizer=reg, ######## TRY WITHOUT !
                     activation='relu', input_shape=input_shape))
    #model.add(MaxPooling1D(3))
    model.add(AveragePooling1D(5))
    model.add(Flatten())
    model.add(Dense(9, activation='relu'))
    model.add(Dropout(0.2))
    model.add(Dense(6, activation='relu'))
    model.add(Dropout(0.2))
    #model.add(Dense(10, activation='relu'))
    #model.add(Dropout(0.3))
model.add(Dense(n_class, activation='softmax')) # softmax !

print('----- Model',NCONV,'-----')
print(model.summary())

# optimizers
# .SGD(lr=0.01, momentum=0.9, nesterov=True) # decay=1e-6,
# .RMSprop()
# .Nadam()
opt = tf.keras.optimizers.Adam()

# compile the model
# categorical_crossentropy, 3 output nodes
model.compile(loss=keras.losses.categorical_crossentropy,
              optimizer=opt,metrics=['accuracy'])
# Out:
# /home/phuniverse/Desktop/master/LCP/Module_B/.venv/lib/python3.13/site-packages/keras/src/layers/convolutional/base_conv.py:113: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 2026-03-16 23:22:13.393672: E external/local_xla/xla/stream_executor/cuda/cuda_platform.cc:51] failed call to cuInit: INTERNAL: CUDA error: Failed call to cuInit: UNKNOWN ERROR (303)
# ----- Model 1 -----
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv1d (Conv1D)                 │ (None, 50, 5)          │            60 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ average_pooling1d               │ (None, 10, 5)          │             0 │
# │ (AveragePooling1D)              │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv1d_1 (Conv1D)               │ (None, 4, 5)           │           180 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten (Flatten)               │ (None, 20)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 12)             │           252 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 12)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 3)              │            39 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 531 (2.07 KB)
#  Trainable params: 531 (2.07 KB)
#  Non-trainable params: 0 (0.00 B)
# None

# %%
model.layers
# Out:
# [<Conv1D name=conv1d, built=True>,
#  <AveragePooling1D name=average_pooling1d, built=True>,
#  <Conv1D name=conv1d_1, built=True>,
#  <Flatten name=flatten, built=True>,
#  <Dense name=dense, built=True>,
#  <Dropout name=dropout, built=True>,
#  <Dense name=dense_1, built=True>]

# %%
y.shape
# Out:
# (10000, 3)

# %%
def Show_weights(model,l=0,label="model"):
    c=['r','y','c','b','m']
    m=['o','s','D','<','>']
    ms=10
    
    w = model.layers[l].get_weights()[0] # weights
    print(w.shape)
    wT=w.T
    print(wT.shape)
    M=len(wT)
    b = model.layers[l].get_weights()[1] # bias
    
    fig,AX=plt.subplots(1,2,figsize=(12,4.4))
    ax=AX[0]
    ax.axhline(0, c="k")
    ax.plot((0,))
    for i in range(M):
        ax.plot(wT[i][0],"-",c=c[i],marker=m[i],label=str(i),markersize=ms)
    ax.set_title(label+': filters of layer '+str(l))
    ax.set_xlabel('index')
    ax=AX[1]
    ax.axhline(0, c="k")
    for i in range(M):
        ax.plot((i),(b[i]),c=c[i],marker=m[i],label="filter "+str(i),markersize=ms)
    ax.set_title(label+': bias of layer '+str(l))
    ax.set_xlabel('filter nr')
    ax.set_xticks(np.arange(5))
    ax.legend()
    plt.show()
    
Show_weights(model,0)
Show_weights(model,2)
# Out:
# (11, 1, 5)
# (5, 1, 11)
# (7, 5, 5)
# (5, 5, 7)

# %%
# ...LESSON ...
# Hyper-parameters
# with small minibatch it does not converge!! 
BATCH_SIZE = 200
EPOCHS = 150

print('----- Model ',NCONV,'-----\nFITTING....')
fit = model.fit(x_train,y_train,batch_size=BATCH_SIZE,
                epochs=EPOCHS,
                validation_data=(x_val, y_val),
                verbose=2, shuffle=True)
# Out:
# ----- Model  1 -----
# FITTING....
# Epoch 1/150
# 40/40 - 4s - 108ms/step - accuracy: 0.3231 - loss: 1.1224 - val_accuracy: 0.3760 - val_loss: 1.1029
# Epoch 2/150
# 40/40 - 1s - 14ms/step - accuracy: 0.4404 - loss: 1.0885 - val_accuracy: 0.4950 - val_loss: 1.0651
# Epoch 3/150
# 40/40 - 1s - 13ms/step - accuracy: 0.5102 - loss: 1.0421 - val_accuracy: 0.6180 - val_loss: 0.9994
# Epoch 4/150
# 40/40 - 1s - 13ms/step - accuracy: 0.6248 - loss: 0.9664 - val_accuracy: 0.7260 - val_loss: 0.8983
# Epoch 5/150
# 40/40 - 1s - 14ms/step - accuracy: 0.7147 - loss: 0.8583 - val_accuracy: 0.7915 - val_loss: 0.7649
# Epoch 6/150
# 40/40 - 1s - 16ms/step - accuracy: 0.7782 - loss: 0.7270 - val_accuracy: 0.8440 - val_loss: 0.6225
# Epoch 7/150
# 40/40 - 1s - 13ms/step - accuracy: 0.8207 - loss: 0.6100 - val_accuracy: 0.8785 - val_loss: 0.5080
# Epoch 8/150
# 40/40 - 1s - 13ms/step - accuracy: 0.8550 - loss: 0.5169 - val_accuracy: 0.8960 - val_loss: 0.4306
# Epoch 9/150
# 40/40 - 1s - 13ms/step - accuracy: 0.8706 - loss: 0.4582 - val_accuracy: 0.9070 - val_loss: 0.3803
# Epoch 10/150
# 40/40 - 0s - 12ms/step - accuracy: 0.8913 - loss: 0.4115 - val_accuracy: 0.9165 - val_loss: 0.3456
# Epoch 11/150
# 40/40 - 1s - 13ms/step - accuracy: 0.8991 - loss: 0.3796 - val_accuracy: 0.9265 - val_loss: 0.3171
# Epoch 12/150
# 40/40 - 1s - 13ms/step - accuracy: 0.9084 - loss: 0.3517 - val_accuracy: 0.9285 - val_loss: 0.2990
# Epoch 13/150
# 40/40 - 1s - 14ms/step - accuracy: 0.9153 - loss: 0.3277 - val_accuracy: 0.9305 - val_loss: 0.2802
# Epoch 14/150
# 40/40 - 1s - 14ms/step - accuracy: 0.9181 - loss: 0.3184 - val_accuracy: 0.9345 - val_loss: 0.2678
# Epoch 15/150
# 40/40 - 1s - 14ms/step - accuracy: 0.9204 - loss: 0.3037 - val_accuracy: 0.9390 - val_loss: 0.2591
# Epoch 16/150
# 40/40 - 1s - 13ms/step - accuracy: 0.9251 - loss: 0.2913 - val_accuracy: 0.9410 - val_loss: 0.2477
# Epoch 17/150
# 40/40 - 1s - 15ms/step - accuracy: 0.9287 - loss: 0.2818 - val_accuracy: 0.9435 - val_loss: 0.2377
# Epoch 18/150
# 40/40 - 1s - 15ms/step - accuracy: 0.9329 - loss: 0.2681 - val_accuracy: 0.9450 - val_loss: 0.2294
# Epoch 19/150
# 40/40 - 1s - 14ms/step - accuracy: 0.9325 - loss: 0.2609 - val_accuracy: 0.9450 - val_loss: 0.2236
# Epoch 20/150
# 40/40 - 1s - 13ms/step - accuracy: 0.9371 - loss: 0.2557 - val_accuracy: 0.9440 - val_loss: 0.2180
# Epoch 21/150
# 40/40 - 1s - 13ms/step - accuracy: 0.9402 - loss: 0.2453 - val_accuracy: 0.9490 - val_loss: 0.2085
# Epoch 22/150
# 40/40 - 1s - 13ms/step - accuracy: 0.9394 - loss: 0.2418 - val_accuracy: 0.9490 - val_loss: 0.2046
# Epoch 23/150
# 40/40 - 0s - 12ms/step - accuracy: 0.9430 - loss: 0.2316 - val_accuracy: 0.9510 - val_loss: 0.1986
# Epoch 24/150
# 40/40 - 0s - 12ms/step - accuracy: 0.9461 - loss: 0.2258 - val_accuracy: 0.9530 - val_loss: 0.1936
# Epoch 25/150
# 40/40 - 0s - 11ms/step - accuracy: 0.9438 - loss: 0.2205 - val_accuracy: 0.9530 - val_loss: 0.1871
# Epoch 26/150
# 40/40 - 0s - 11ms/step - accuracy: 0.9473 - loss: 0.2194 - val_accuracy: 0.9560 - val_loss: 0.1849
# Epoch 27/150
# 40/40 - 0s - 10ms/step - accuracy: 0.9486 - loss: 0.2109 - val_accuracy: 0.9580 - val_loss: 0.1787
# Epoch 28/150
# 40/40 - 0s - 10ms/step - accuracy: 0.9496 - loss: 0.2046 - val_accuracy: 0.9570 - val_loss: 0.1741
# Epoch 29/150
# 40/40 - 0s - 11ms/step - accuracy: 0.9504 - loss: 0.2047 - val_accuracy: 0.9595 - val_loss: 0.1697
# Epoch 30/150
# 40/40 - 0s - 11ms/step - accuracy: 0.9523 - loss: 0.1999 - val_accuracy: 0.9565 - val_loss: 0.1719
# Epoch 31/150
# 40/40 - 0s - 11ms/step - accuracy: 0.9542 - loss: 0.1963 - val_accuracy: 0.9600 - val_loss: 0.1652
# Epoch 32/150
# 40/40 - 0s - 12ms/step - accuracy: 0.9561 - loss: 0.1896 - val_accuracy: 0.9605 - val_loss: 0.1614
# Epoch 33/150
# 40/40 - 0s - 10ms/step - accuracy: 0.9559 - loss: 0.1889 - val_accuracy: 0.9645 - val_loss: 0.1559
# Epoch 34/150
# 40/40 - 0s - 11ms/step - accuracy: 0.9565 - loss: 0.1864 - val_accuracy: 0.9605 - val_loss: 0.1580
# Epoch 35/150
# 40/40 - 1s - 14ms/step - accuracy: 0.9579 - loss: 0.1825 - val_accuracy: 0.9640 - val_loss: 0.1538
# Epoch 36/150
# 40/40 - 1s - 13ms/step - accuracy: 0.9554 - loss: 0.1788 - val_accuracy: 0.9615 - val_loss: 0.1528
# Epoch 37/150
# 40/40 - 1s - 13ms/step - accuracy: 0.9599 - loss: 0.1744 - val_accuracy: 0.9650 - val_loss: 0.1471
# Epoch 38/150
# 40/40 - 1s - 13ms/step - accuracy: 0.9611 - loss: 0.1692 - val_accuracy: 0.9675 - val_loss: 0.1431
# Epoch 39/150
# 40/40 - 1s - 15ms/step - accuracy: 0.9629 - loss: 0.1651 - val_accuracy: 0.9645 - val_loss: 0.1455
# Epoch 40/150
# 40/40 - 1s - 13ms/step - accuracy: 0.9606 - loss: 0.1656 - val_accuracy: 0.9690 - val_loss: 0.1384
# Epoch 41/150
# 40/40 - 1s - 13ms/step - accuracy: 0.9589 - loss: 0.1670 - val_accuracy: 0.9700 - val_loss: 0.1354
# Epoch 42/150
# 40/40 - 1s - 13ms/step - accuracy: 0.9614 - loss: 0.1644 - val_accuracy: 0.9705 - val_loss: 0.1325
# Epoch 43/150
# 40/40 - 1s - 13ms/step - accuracy: 0.9621 - loss: 0.1597 - val_accuracy: 0.9705 - val_loss: 0.1338
# Epoch 44/150
# 40/40 - 1s - 14ms/step - accuracy: 0.9630 - loss: 0.1558 - val_accuracy: 0.9710 - val_loss: 0.1289
# Epoch 45/150
# 40/40 - 1s - 15ms/step - accuracy: 0.9641 - loss: 0.1531 - val_accuracy: 0.9710 - val_loss: 0.1269
# Epoch 46/150
# 40/40 - 1s - 13ms/step - accuracy: 0.9632 - loss: 0.1527 - val_accuracy: 0.9720 - val_loss: 0.1293
# Epoch 47/150
# 40/40 - 0s - 12ms/step - accuracy: 0.9668 - loss: 0.1488 - val_accuracy: 0.9710 - val_loss: 0.1237
# Epoch 48/150
# 40/40 - 1s - 13ms/step - accuracy: 0.9640 - loss: 0.1484 - val_accuracy: 0.9740 - val_loss: 0.1216
# Epoch 49/150
# 40/40 - 1s - 13ms/step - accuracy: 0.9645 - loss: 0.1465 - val_accuracy: 0.9735 - val_loss: 0.1213
# Epoch 50/150
# 40/40 - 1s - 13ms/step - accuracy: 0.9684 - loss: 0.1412 - val_accuracy: 0.9725 - val_loss: 0.1197
# Epoch 51/150
# 40/40 - 1s - 16ms/step - accuracy: 0.9684 - loss: 0.1416 - val_accuracy: 0.9725 - val_loss: 0.1185
# Epoch 52/150
# 40/40 - 1s - 16ms/step - accuracy: 0.9679 - loss: 0.1404 - val_accuracy: 0.9745 - val_loss: 0.1152
# Epoch 53/150
# 40/40 - 1s - 16ms/step - accuracy: 0.9651 - loss: 0.1439 - val_accuracy: 0.9735 - val_loss: 0.1158
# Epoch 54/150
# 40/40 - 1s - 16ms/step - accuracy: 0.9695 - loss: 0.1379 - val_accuracy: 0.9740 - val_loss: 0.1126
# Epoch 55/150
# 40/40 - 1s - 13ms/step - accuracy: 0.9699 - loss: 0.1355 - val_accuracy: 0.9770 - val_loss: 0.1098
# Epoch 56/150
# 40/40 - 0s - 12ms/step - accuracy: 0.9699 - loss: 0.1374 - val_accuracy: 0.9735 - val_loss: 0.1112
# Epoch 57/150
# 40/40 - 1s - 13ms/step - accuracy: 0.9690 - loss: 0.1324 - val_accuracy: 0.9750 - val_loss: 0.1129
# Epoch 58/150
# 40/40 - 1s - 14ms/step - accuracy: 0.9709 - loss: 0.1284 - val_accuracy: 0.9770 - val_loss: 0.1068
# Epoch 59/150
# 40/40 - 1s - 16ms/step - accuracy: 0.9728 - loss: 0.1262 - val_accuracy: 0.9765 - val_loss: 0.1089
# Epoch 60/150
# 40/40 - 1s - 16ms/step - accuracy: 0.9720 - loss: 0.1306 - val_accuracy: 0.9785 - val_loss: 0.1049
# Epoch 61/150
# 40/40 - 1s - 13ms/step - accuracy: 0.9706 - loss: 0.1278 - val_accuracy: 0.9760 - val_loss: 0.1054
# Epoch 62/150
# 40/40 - 1s - 13ms/step - accuracy: 0.9704 - loss: 0.1247 - val_accuracy: 0.9785 - val_loss: 0.1033
# Epoch 63/150
# 40/40 - 1s - 13ms/step - accuracy: 0.9715 - loss: 0.1236 - val_accuracy: 0.9765 - val_loss: 0.1034
# Epoch 64/150
# 40/40 - 1s - 13ms/step - accuracy: 0.9690 - loss: 0.1242 - val_accuracy: 0.9765 - val_loss: 0.1024
# Epoch 65/150
# 40/40 - 1s - 15ms/step - accuracy: 0.9718 - loss: 0.1232 - val_accuracy: 0.9775 - val_loss: 0.1029
# Epoch 66/150
# 40/40 - 1s - 13ms/step - accuracy: 0.9724 - loss: 0.1203 - val_accuracy: 0.9780 - val_loss: 0.1001
# Epoch 67/150
# 40/40 - 0s - 12ms/step - accuracy: 0.9719 - loss: 0.1212 - val_accuracy: 0.9775 - val_loss: 0.1015
# Epoch 68/150
# 40/40 - 1s - 13ms/step - accuracy: 0.9709 - loss: 0.1164 - val_accuracy: 0.9780 - val_loss: 0.0982
# Epoch 69/150
# 40/40 - 1s - 13ms/step - accuracy: 0.9719 - loss: 0.1173 - val_accuracy: 0.9775 - val_loss: 0.0987
# Epoch 70/150
# 40/40 - 1s - 14ms/step - accuracy: 0.9746 - loss: 0.1170 - val_accuracy: 0.9775 - val_loss: 0.0968
# Epoch 71/150
# 40/40 - 1s - 15ms/step - accuracy: 0.9710 - loss: 0.1186 - val_accuracy: 0.9800 - val_loss: 0.0973
# Epoch 72/150
# 40/40 - 1s - 16ms/step - accuracy: 0.9741 - loss: 0.1150 - val_accuracy: 0.9775 - val_loss: 0.0972
# Epoch 73/150
# 40/40 - 1s - 16ms/step - accuracy: 0.9753 - loss: 0.1124 - val_accuracy: 0.9790 - val_loss: 0.0947
# Epoch 74/150
# 40/40 - 1s - 13ms/step - accuracy: 0.9750 - loss: 0.1123 - val_accuracy: 0.9790 - val_loss: 0.0951
# Epoch 75/150
# 40/40 - 1s - 13ms/step - accuracy: 0.9736 - loss: 0.1133 - val_accuracy: 0.9790 - val_loss: 0.0925
# Epoch 76/150
# 40/40 - 1s - 14ms/step - accuracy: 0.9732 - loss: 0.1109 - val_accuracy: 0.9805 - val_loss: 0.0919
# Epoch 77/150
# 40/40 - 1s - 13ms/step - accuracy: 0.9756 - loss: 0.1111 - val_accuracy: 0.9810 - val_loss: 0.0907
# Epoch 78/150
# 40/40 - 1s - 13ms/step - accuracy: 0.9715 - loss: 0.1128 - val_accuracy: 0.9790 - val_loss: 0.0934
# Epoch 79/150
# 40/40 - 1s - 16ms/step - accuracy: 0.9761 - loss: 0.1059 - val_accuracy: 0.9795 - val_loss: 0.0924
# Epoch 80/150
# 40/40 - 1s - 17ms/step - accuracy: 0.9753 - loss: 0.1122 - val_accuracy: 0.9805 - val_loss: 0.0912
# Epoch 81/150
# 40/40 - 1s - 16ms/step - accuracy: 0.9778 - loss: 0.1022 - val_accuracy: 0.9775 - val_loss: 0.0937
# Epoch 82/150
# 40/40 - 1s - 13ms/step - accuracy: 0.9769 - loss: 0.1036 - val_accuracy: 0.9795 - val_loss: 0.0919
# Epoch 83/150
# 40/40 - 1s - 14ms/step - accuracy: 0.9739 - loss: 0.1058 - val_accuracy: 0.9790 - val_loss: 0.0922
# Epoch 84/150
# 40/40 - 1s - 13ms/step - accuracy: 0.9740 - loss: 0.1091 - val_accuracy: 0.9785 - val_loss: 0.0911
# Epoch 85/150
# 40/40 - 1s - 15ms/step - accuracy: 0.9741 - loss: 0.1065 - val_accuracy: 0.9805 - val_loss: 0.0882
# Epoch 86/150
# 40/40 - 1s - 15ms/step - accuracy: 0.9794 - loss: 0.0985 - val_accuracy: 0.9805 - val_loss: 0.0869
# Epoch 87/150
# 40/40 - 1s - 14ms/step - accuracy: 0.9751 - loss: 0.1030 - val_accuracy: 0.9800 - val_loss: 0.0886
# Epoch 88/150
# 40/40 - 1s - 15ms/step - accuracy: 0.9756 - loss: 0.0994 - val_accuracy: 0.9800 - val_loss: 0.0867
# Epoch 89/150
# 40/40 - 1s - 15ms/step - accuracy: 0.9743 - loss: 0.1032 - val_accuracy: 0.9795 - val_loss: 0.0891
# Epoch 90/150
# 40/40 - 1s - 15ms/step - accuracy: 0.9768 - loss: 0.1019 - val_accuracy: 0.9795 - val_loss: 0.0874
# Epoch 91/150
# 40/40 - 1s - 15ms/step - accuracy: 0.9758 - loss: 0.0992 - val_accuracy: 0.9795 - val_loss: 0.0869
# Epoch 92/150
# 40/40 - 1s - 15ms/step - accuracy: 0.9774 - loss: 0.1017 - val_accuracy: 0.9810 - val_loss: 0.0873
# Epoch 93/150
# 40/40 - 1s - 15ms/step - accuracy: 0.9772 - loss: 0.0995 - val_accuracy: 0.9805 - val_loss: 0.0853
# Epoch 94/150
# 40/40 - 1s - 16ms/step - accuracy: 0.9774 - loss: 0.0967 - val_accuracy: 0.9805 - val_loss: 0.0844
# Epoch 95/150
# 40/40 - 1s - 15ms/step - accuracy: 0.9764 - loss: 0.1000 - val_accuracy: 0.9795 - val_loss: 0.0861
# Epoch 96/150
# 40/40 - 1s - 15ms/step - accuracy: 0.9780 - loss: 0.0993 - val_accuracy: 0.9800 - val_loss: 0.0847
# Epoch 97/150
# 40/40 - 1s - 15ms/step - accuracy: 0.9761 - loss: 0.0984 - val_accuracy: 0.9800 - val_loss: 0.0836
# Epoch 98/150
# 40/40 - 1s - 15ms/step - accuracy: 0.9778 - loss: 0.0954 - val_accuracy: 0.9800 - val_loss: 0.0847
# Epoch 99/150
# 40/40 - 1s - 15ms/step - accuracy: 0.9776 - loss: 0.0977 - val_accuracy: 0.9805 - val_loss: 0.0812
# Epoch 100/150
# 40/40 - 1s - 15ms/step - accuracy: 0.9772 - loss: 0.0962 - val_accuracy: 0.9820 - val_loss: 0.0794
# Epoch 101/150
# 40/40 - 1s - 15ms/step - accuracy: 0.9761 - loss: 0.0940 - val_accuracy: 0.9820 - val_loss: 0.0815
# Epoch 102/150
# 40/40 - 1s - 14ms/step - accuracy: 0.9764 - loss: 0.0968 - val_accuracy: 0.9815 - val_loss: 0.0815
# Epoch 103/150
# 40/40 - 1s - 15ms/step - accuracy: 0.9783 - loss: 0.0976 - val_accuracy: 0.9820 - val_loss: 0.0815
# Epoch 104/150
# 40/40 - 1s - 15ms/step - accuracy: 0.9796 - loss: 0.0895 - val_accuracy: 0.9810 - val_loss: 0.0816
# Epoch 105/150
# 40/40 - 1s - 15ms/step - accuracy: 0.9778 - loss: 0.0942 - val_accuracy: 0.9825 - val_loss: 0.0812
# Epoch 106/150
# 40/40 - 1s - 15ms/step - accuracy: 0.9769 - loss: 0.0941 - val_accuracy: 0.9810 - val_loss: 0.0788
# Epoch 107/150
# 40/40 - 1s - 15ms/step - accuracy: 0.9780 - loss: 0.0924 - val_accuracy: 0.9815 - val_loss: 0.0789
# Epoch 108/150
# 40/40 - 1s - 15ms/step - accuracy: 0.9775 - loss: 0.0930 - val_accuracy: 0.9820 - val_loss: 0.0788
# Epoch 109/150
# 40/40 - 1s - 14ms/step - accuracy: 0.9781 - loss: 0.0928 - val_accuracy: 0.9815 - val_loss: 0.0792
# Epoch 110/150
# 40/40 - 1s - 15ms/step - accuracy: 0.9771 - loss: 0.0967 - val_accuracy: 0.9825 - val_loss: 0.0769
# Epoch 111/150
# 40/40 - 1s - 15ms/step - accuracy: 0.9797 - loss: 0.0897 - val_accuracy: 0.9820 - val_loss: 0.0773
# Epoch 112/150
# 40/40 - 1s - 14ms/step - accuracy: 0.9793 - loss: 0.0909 - val_accuracy: 0.9810 - val_loss: 0.0792
# Epoch 113/150
# 40/40 - 1s - 15ms/step - accuracy: 0.9768 - loss: 0.0910 - val_accuracy: 0.9810 - val_loss: 0.0789
# Epoch 114/150
# 40/40 - 1s - 15ms/step - accuracy: 0.9781 - loss: 0.0889 - val_accuracy: 0.9825 - val_loss: 0.0765
# Epoch 115/150
# 40/40 - 1s - 14ms/step - accuracy: 0.9790 - loss: 0.0914 - val_accuracy: 0.9820 - val_loss: 0.0782
# Epoch 116/150
# 40/40 - 0s - 12ms/step - accuracy: 0.9770 - loss: 0.0927 - val_accuracy: 0.9825 - val_loss: 0.0752
# Epoch 117/150
# 40/40 - 1s - 13ms/step - accuracy: 0.9793 - loss: 0.0903 - val_accuracy: 0.9835 - val_loss: 0.0768
# Epoch 118/150
# 40/40 - 1s - 13ms/step - accuracy: 0.9790 - loss: 0.0883 - val_accuracy: 0.9830 - val_loss: 0.0750
# Epoch 119/150
# 40/40 - 1s - 14ms/step - accuracy: 0.9784 - loss: 0.0905 - val_accuracy: 0.9815 - val_loss: 0.0786
# Epoch 120/150
# 40/40 - 1s - 15ms/step - accuracy: 0.9776 - loss: 0.0916 - val_accuracy: 0.9815 - val_loss: 0.0773
# Epoch 121/150
# 40/40 - 1s - 15ms/step - accuracy: 0.9786 - loss: 0.0874 - val_accuracy: 0.9825 - val_loss: 0.0757
# Epoch 122/150
# 40/40 - 1s - 16ms/step - accuracy: 0.9775 - loss: 0.0910 - val_accuracy: 0.9825 - val_loss: 0.0760
# Epoch 123/150
# 40/40 - 1s - 15ms/step - accuracy: 0.9783 - loss: 0.0881 - val_accuracy: 0.9815 - val_loss: 0.0772
# Epoch 124/150
# 40/40 - 1s - 13ms/step - accuracy: 0.9775 - loss: 0.0890 - val_accuracy: 0.9820 - val_loss: 0.0757
# Epoch 125/150
# 40/40 - 1s - 13ms/step - accuracy: 0.9776 - loss: 0.0887 - val_accuracy: 0.9820 - val_loss: 0.0772
# Epoch 126/150
# 40/40 - 1s - 13ms/step - accuracy: 0.9778 - loss: 0.0897 - val_accuracy: 0.9820 - val_loss: 0.0773
# Epoch 127/150
# 40/40 - 1s - 15ms/step - accuracy: 0.9789 - loss: 0.0852 - val_accuracy: 0.9825 - val_loss: 0.0742
# Epoch 128/150
# 40/40 - 1s - 16ms/step - accuracy: 0.9790 - loss: 0.0860 - val_accuracy: 0.9840 - val_loss: 0.0743
# Epoch 129/150
# 40/40 - 1s - 15ms/step - accuracy: 0.9803 - loss: 0.0826 - val_accuracy: 0.9820 - val_loss: 0.0757
# Epoch 130/150
# 40/40 - 1s - 15ms/step - accuracy: 0.9819 - loss: 0.0817 - val_accuracy: 0.9820 - val_loss: 0.0756
# Epoch 131/150
# 40/40 - 1s - 15ms/step - accuracy: 0.9776 - loss: 0.0866 - val_accuracy: 0.9825 - val_loss: 0.0749
# Epoch 132/150
# 40/40 - 1s - 15ms/step - accuracy: 0.9786 - loss: 0.0849 - val_accuracy: 0.9825 - val_loss: 0.0728
# Epoch 133/150
# 40/40 - 1s - 15ms/step - accuracy: 0.9785 - loss: 0.0848 - val_accuracy: 0.9820 - val_loss: 0.0755
# Epoch 134/150
# 40/40 - 1s - 15ms/step - accuracy: 0.9794 - loss: 0.0850 - val_accuracy: 0.9800 - val_loss: 0.0794
# Epoch 135/150
# 40/40 - 1s - 15ms/step - accuracy: 0.9796 - loss: 0.0850 - val_accuracy: 0.9835 - val_loss: 0.0719
# Epoch 136/150
# 40/40 - 1s - 15ms/step - accuracy: 0.9771 - loss: 0.0859 - val_accuracy: 0.9830 - val_loss: 0.0723
# Epoch 137/150
# 40/40 - 1s - 15ms/step - accuracy: 0.9797 - loss: 0.0828 - val_accuracy: 0.9825 - val_loss: 0.0745
# Epoch 138/150
# 40/40 - 1s - 15ms/step - accuracy: 0.9797 - loss: 0.0837 - val_accuracy: 0.9825 - val_loss: 0.0745
# Epoch 139/150
# 40/40 - 1s - 15ms/step - accuracy: 0.9808 - loss: 0.0782 - val_accuracy: 0.9840 - val_loss: 0.0701
# Epoch 140/150
# 40/40 - 1s - 15ms/step - accuracy: 0.9806 - loss: 0.0799 - val_accuracy: 0.9820 - val_loss: 0.0730
# Epoch 141/150
# 40/40 - 1s - 14ms/step - accuracy: 0.9812 - loss: 0.0829 - val_accuracy: 0.9825 - val_loss: 0.0727
# Epoch 142/150
# 40/40 - 1s - 13ms/step - accuracy: 0.9815 - loss: 0.0806 - val_accuracy: 0.9840 - val_loss: 0.0718
# Epoch 143/150
# 40/40 - 1s - 13ms/step - accuracy: 0.9796 - loss: 0.0818 - val_accuracy: 0.9835 - val_loss: 0.0721
# Epoch 144/150
# 40/40 - 1s - 14ms/step - accuracy: 0.9799 - loss: 0.0786 - val_accuracy: 0.9855 - val_loss: 0.0711
# Epoch 145/150
# 40/40 - 1s - 15ms/step - accuracy: 0.9791 - loss: 0.0802 - val_accuracy: 0.9820 - val_loss: 0.0745
# Epoch 146/150
# 40/40 - 1s - 15ms/step - accuracy: 0.9805 - loss: 0.0815 - val_accuracy: 0.9835 - val_loss: 0.0720
# Epoch 147/150
# 40/40 - 1s - 15ms/step - accuracy: 0.9806 - loss: 0.0792 - val_accuracy: 0.9825 - val_loss: 0.0750
# Epoch 148/150
# 40/40 - 1s - 15ms/step - accuracy: 0.9786 - loss: 0.0823 - val_accuracy: 0.9845 - val_loss: 0.0703
# Epoch 149/150
# 40/40 - 1s - 15ms/step - accuracy: 0.9786 - loss: 0.0784 - val_accuracy: 0.9840 - val_loss: 0.0715
# Epoch 150/150
# 40/40 - 1s - 15ms/step - accuracy: 0.9803 - loss: 0.0784 - val_accuracy: 0.9840 - val_loss: 0.0714

# %%
def Show_history(fit):
    fig,AX=plt.subplots(1,2,figsize=(12,5.))
    ax=AX[0] 
    ax.plot(fit.history['accuracy'],"b",label="train")
    ax.plot(fit.history['val_accuracy'],"r--",label="valid.")
    ax.plot((0,EPOCHS),(1/3,1/3),":",c="gray",label="random choice")
    ax.set_xlabel('epoch')
    ax.set_ylabel("Accuracy")
    ax.set_ylim([0, 1])
    ax.legend()
    ax=AX[1]
    ax.plot(fit.history['loss'],"b",label="train")
    ax.plot(fit.history['val_loss'],"r--",label="valid.")
    ax.set_xlabel('epoch')
    ax.set_ylabel("Loss")
    ax.set_ylim([0, 1.05*np.max(fit.history['loss'])])
    ax.legend()
    plt.show()
Show_history(fit)
Show_weights(model,0)
Show_weights(model,2)
# Out:
# (11, 1, 5)
# (5, 1, 11)
# (7, 5, 5)
# (5, 5, 7)

# %%
# ...LESSON ...
reg2 = tf.keras.regularizers.l1(0.5)
model2 = keras.models.clone_model(model)
model2.layers[0].kernel_regularizer = reg2
model2.layers[2].kernel_regularizer = reg2
opt2 = tf.keras.optimizers.Adam()   # NEW optimizer instance
model2.compile(loss=keras.losses.categorical_crossentropy,optimizer=opt2,metrics=['accuracy'])

BATCH_SIZE2 = 200
EPOCHS2 = 150

fit2 = model2.fit(x_train,y_train,batch_size=BATCH_SIZE2,epochs=EPOCHS2,
                validation_data=(x_val, y_val), verbose=2, shuffle=True)

# %%
Show_history(fit)
Show_history(fit2)
Show_weights(model2,0,label="model2")
Show_weights(model2,2,label="model2")

# %%
# confusion table: compare true labels with predicted ones
import pandas as pd
from scipy import stats

import seaborn 
from sklearn import metrics

from sklearn.metrics import classification_report
from sklearn import preprocessing

LABELS = ["absent","positive","negative"] # from labels y 
cmap="GnBu"

def show_confusion_matrix(validations, predictions, label="Model"):

    matrix = metrics.confusion_matrix(validations, predictions)
    plt.figure(figsize=(6, 5))
    seaborn.heatmap(matrix,
                xticklabels=LABELS,
                yticklabels=LABELS,
                annot=True,
                fmt='d',
                linecolor='white',
                linewidths=1,
                cmap=cmap)
    plt.title(label+': Confusion Matrix')
    plt.ylabel('True Label')
    plt.xlabel('Predicted Label')
    plt.show()

y_pred_val = model.predict(x_val)
y_pred_val2 = model2.predict(x_val)
# Take the class with the highest probability from the val predictions
max_y_pred_val = np.argmax(y_pred_val, axis=1)
max_y_val = np.argmax(y_val, axis=1)
max_y_pred_val2 = np.argmax(y_pred_val2, axis=1)

show_confusion_matrix(max_y_val, max_y_pred_val)
show_confusion_matrix(max_y_val, max_y_pred_val2, label="Model 2")

#print(classification_report(max_y_val, max_y_pred_val))
